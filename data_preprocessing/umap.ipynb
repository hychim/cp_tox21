# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
tox21 = pd.read_csv("data/tox21_averaged.csv")

# %%
tox21
# Out:
#     Compound_ID  ImageNumber_nuclei  ObjectNumber_nuclei  \
# 0     CBK015802                   1            55.656638
# 1     CBK040817                   1            86.752593
# 2     CBK041480                   1            80.058971
# 3     CBK041954                   1            52.362824
# 4     CBK200682                   1            39.328657
# ..          ...                 ...                  ...
# 139   CBK309456                   1            83.164674
# 140   CBK309460                   1            71.154167
# 141   CBK309473                   1            82.848916
# 142   CBK309576                   1            84.462755
# 143   CBK309745                   1            86.682583
#
#      Metadata_Site_nuclei  AreaShape_Area_nuclei  \
# 0                5.173913            3056.394850
# 1                5.040816            2503.896230
# 2                4.958333            2535.108163
# 3                5.122449            3026.931357
# ...

# %%
X = tox21.iloc[:, 1:-2]
y = tox21.iloc[:, -1]

# %%
import umap.umap_ as umap

# %%
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
reducer = umap.UMAP()

# %%
X = tox21.iloc[:, 1:-2]
scaled_data = StandardScaler().fit_transform(X)
embedding = reducer.fit_transform(scaled_data)

# %%
tox21.Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 139    0
# 140    0
# 141    0
# 142    0
# 143    0
# Name: Y, Length: 144, dtype: int64

# %%
plt.scatter(
    embedding[:, 0],
    embedding[:, 1],
    c=[sns.color_palette()[x] for x in tox21.Y])
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the tox21 dataset', fontsize=24)
plt.show()

# %%
tox21_mito = pd.read_csv("data/tox21_averaged_mito.csv")

# %%
tox21_mito
# Out:
#                            Tox21_assay Compound_ID  ImageNumber_nuclei  \
# 0    aryl hydrocarbon receptor agonist   CBK015802                 1.0
# 1    aryl hydrocarbon receptor agonist   CBK040817                 1.0
# 2    aryl hydrocarbon receptor agonist   CBK041480                 1.0
# 3    aryl hydrocarbon receptor agonist   CBK041954                 1.0
# 4    aryl hydrocarbon receptor agonist   CBK200682                 1.0
# ..                                 ...         ...                 ...
# 146                           inactive   CBK309456                 1.0
# 147                           inactive   CBK309460                 1.0
# 148                           inactive   CBK309473                 1.0
# 149                           inactive   CBK309576                 1.0
# 150                           inactive   CBK309745                 1.0
#
#      ObjectNumber_nuclei  Metadata_Site_nuclei  AreaShape_Area_nuclei  \
# ...

# %%
X = tox21_mito.iloc[:, 2:-1]
y = tox21_mito.iloc[:, -1]

scaled_data = StandardScaler().fit_transform(X)
embedding = reducer.fit_transform(scaled_data)

plt.scatter(
    embedding[:, 0],
    embedding[:, 1],
    c=[sns.color_palette()[x] for x in tox21_mito.dummy_encoding])
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the tox21 dataset', fontsize=24)
plt.show()
